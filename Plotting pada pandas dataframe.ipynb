# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.5.3

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.25.2

# %%
import matplotlib.pyplot as plt

# %%
n_rows = 40
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)),
                  columns=cols)
df.head()
# Out:
#     A   B   C   D   E
# 0  19  15   7  14   8
# 1   2  16  17  14  16
# 2   8  16   7   6   2
# 3  17  17  11   1  14
# 4  15   7   3   3   8

# %%
line plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19  15   7  14   8
# 1   2  16  17  14  16
# 2   8  16   7   6   2
# 3  17  17  11   1  14
# 4  15   7   3   3   8

# %%
df.plot(kind='line')
plt.show()

# %%
df[['A', 'B']].plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
Bar plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19  15   7  14   8
# 1   2  16  17  14  16
# 2   8  16   7   6   2
# 3  17  17  11   1  14
# 4  15   7   3   3   8

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[['A', 'B']].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[['A', 'B']].head().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[['A', 'B']].head().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
Area Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19  15   7  14   8
# 1   2  16  17  14  16
# 2   8  16   7   6   2
# 3  17  17  11   1  14
# 4  15   7   3   3   8

# %%
df.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
df[['A', 'B']].head().plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
Box plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19  15   7  14   8
# 1   2  16  17  14  16
# 2   8  16   7   6   2
# 3  17  17  11   1  14
# 4  15   7   3   3   8

# %%
df.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
Histogram

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19  15   7  14   8
# 1   2  16  17  14  16
# 2   8  16   7   6   2
# 3  17  17  11   1  14
# 4  15   7   3   3   8

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['A', 'B']].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
Kernel Density Estimation (KDE)

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19  15   7  14   8
# 1   2  16  17  14  16
# 2   8  16   7   6   2
# 3  17  17  11   1  14
# 4  15   7   3   3   8

# %%
df.plot(kind='kde')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df.plot(kind='kde')
#
# File /lib/python3.11/site-packages/pandas/plotting/_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /lib/python3.11/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File /lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:452, in MPLPlot.generate(self)
#     450 self._compute_plot_data()
#     451 self._setup_subplots()
# --> 452 self._make_plot()
#     453 self._add_table()
#     454 self._make_legend()
#
# File /lib/python3.11/site-packages/pandas/plotting/_matplotlib/hist.py:154, in HistPlot._make_plot(self)
#     151 if weights is not None and np.ndim(weights) != 1:
#     152     kwds["weights"] = weights[:, i]
# --> 154 artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#     156 # when by is applied, show title for subplots to know which group it is
#     157 if self.by is not None:
#
# File /lib/python3.11/site-packages/pandas/plotting/_matplotlib/hist.py:232, in KdePlot._plot(cls, ax, y, style, bw_method, ind, column_num, stacking_id, **kwds)
#     220 @classmethod
#     221 def _plot(
#     222     cls,
#    (...)
#     230     **kwds,
#     231 ):
# --> 232     from scipy.stats import gaussian_kde
#     234     y = remove_na_arraylike(y)
#     235     gkde = gaussian_kde(y, bw_method=bw_method)
#
# ModuleNotFoundError: The module 'scipy' is included in the Pyodide distribution, but it is not installed.
# You can install it by calling:
#   await micropip.install("scipy") in Python, or
#   await pyodide.loadPackage("scipy") in JavaScript
# See https://pyodide.org/en/stable/usage/loading-packages.html for more details.

# %%
scatter plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19  15   7  14   8
# 1   2  16  17  14  16
# 2   8  16   7   6   2
# 3  17  17  11   1  14
# 4  15   7   3   3   8

# %%
df.plot(x='A', y='B', kind='scatter')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>
